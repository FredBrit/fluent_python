# %%
metro_areas = [
    ('Tokyo', 'JP', 36.933, (35.689722, 139.691667)),
    ('Delhi NCR', 'IN', 21.935, (28.613889, 77.208889)),
    ('Mexico City', 'MX', 20.142, (19.433333, -99.133333)),
    ('New York-Newark', 'US', 20.104, (40.808611, -74.020386)),
    ('São Paulo', 'BR', 19.649, (-23.547778, -46.635833)),
]
def main():
    print(f'{"":15} | {"latitude":>9} | {"longitude":>9}')
    for record in metro_areas:
        match record:
            case [name, _, _, (lat, lon)] if lon <= 0:
                print(f'{name:15} | {lat: 9.4f} | {lon: 9.4f}')

if __name__ == '__main__':
    main()
# Out:
#                 |  latitude | longitude
# Mexico City     |   19.4333 |  -99.1333
# New York-Newark |   40.8086 |  -74.0204
# São Paulo       |  -23.5478 |  -46.6358

# %%
metro_areas = [
    ('Tokyo', 'JP', 36.933, (35.689722, 139.691667)),
    ('Delhi NCR', 'IN', 21.935, (28.613889, 77.208889)),
    ('Mexico City', 'MX', 20.142, (19.433333, -99.133333)),
    ('New York-Newark', 'US', 20.104, (40.808611, -74.020386)),
    ('São Paulo', 'BR', 19.649, (-23.547778, -46.635833)),
]
def main():
    print(f'{"":15} | {"latitude":>9} | {"longitude":>9}')
    for record in metro_areas:
        match record:
            case [str(name), *_, (float(lat), float(lon))] if lon <= 0:
                print(f'{name:15} | {lat: 9.4f} | {lon: 9.4f}')

if __name__ == '__main__':
    main()
# Out:
#                 |  latitude | longitude
# Mexico City     |   19.4333 |  -99.1333
# New York-Newark |   40.8086 |  -74.0204
# São Paulo       |  -23.5478 |  -46.6358

# %%
metro_areas = [
    ('Tokyo', 'JP', 36.933, (35.689722, 139.691667)),
    ('Delhi NCR', 'IN', 21.935, (28.613889, 77.208889)),
    ('Mexico City', 'MX', 20.142, (19.433333, -99.133333)),
    ('New York-Newark', 'US', 20.104, (40.808611, -74.020386)),
    ('São Paulo', 'BR', 19.649, (-23.547778, -46.635833)),
]
def main():
    print(f'{"":15} | {"latitude":>9} | {"longitude":>9}')
    for record in metro_areas:
        match record:
            case [str(name), *extra, (float(lat), float(lon))] if lon <= 0:
                print(f'{name:15} | {extra} | {lat: 9.4f} | {lon: 9.4f}')

if __name__ == '__main__':
    main()
# Out:
#                 |  latitude | longitude
# Mexico City     | ['MX', 20.142] |   19.4333 |  -99.1333
# New York-Newark | ['US', 20.104] |   40.8086 |  -74.0204
# São Paulo       | ['BR', 19.649] |  -23.5478 |  -46.6358

# %%
metro_areas = [
    ('Tokyo', 'JP', 36.933, (35.689722, 139.691667)),
    ('Delhi NCR', 'IN', 21.935, (28.613889, 77.208889)),
    ('Mexico City', 'MX', 20.142, (19.433333, -99.133333)),
    ('New York-Newark', 'US', 20.104, (40.808611, -74.020386)),
    ('São Paulo', 'BR', 19.649, (-23.547778, -46.635833)),
]
def main():
    res=[]
    for record in metro_areas:
        match record:
            case [name, _, _, (lat, lon)] if lon <= 0:
                res.append((name,lat,lon))
    return res            

if __name__ == '__main__':
    print(main())
# Out:
# [('Mexico City', 19.433333, -99.133333), ('New York-Newark', 40.808611, -74.020386), ('São Paulo', -23.547778, -46.635833)]

# %%
def ex():
    phone='89817206840'
    match tuple(phone):
        case ['1', *rest]: # Северная Америка и страны Карибского бассейна
            ...
        case ['2', *rest]: # Африка и некоторые другие территории
            ...
        case ['3' | '4', *rest]: # Европа
            return 'Europe'
        case ['8',*rest]:
            return 'Russia'
ex()
# Out:
# 'Russia'
