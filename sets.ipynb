# %%
dial_codes = [ (880, 'Bangladesh'),
(55, 'Brazil'),
(86, 'China'),
(91, 'India'),
(62, 'Indonesia'),
(81, 'Japan'),
(234, 'Nigeria'),
(92, 'Pakistan'),
(7, 'Russia'),
(1, 'United States'),
]
dict_codes={country:code for country,code in dial_codes}
dict_codes
# Out:
# {880: 'Bangladesh',
#  55: 'Brazil',
#  86: 'China',
#  91: 'India',
#  62: 'Indonesia',
#  81: 'Japan',
#  234: 'Nigeria',
#  92: 'Pakistan',
#  7: 'Russia',
#  1: 'United States'}

# %%
dict_codes2={country:code for code,country in sorted(dict_codes.items()) if code<70}
dict_codes2
# Out:
# {'United States': 1, 'Russia': 7, 'Brazil': 55, 'Indonesia': 62}

# %%
def dump(**kwargs):
    return kwargs

dump(**{'x': 1}, y=2, **{'z': 3})
# Out:
# {'x': 1, 'y': 2, 'z': 3}

# %%
d1 = {'a': 1, 'b': 3}
d2 = {'a': 2, 'b': 4, 'c': 6}
d1 | d2
# Out:
# {'a': 2, 'b': 4, 'c': 6}

# %%
d1 = {'a': 1, 'b': 3}
d2 = {'a': 2, 'b': 4, 'c': 6}
d1 |= d2
d1
# Out:
# {'a': 2, 'b': 4, 'c': 6}
