# %%
l=[1,2,3,4,5]
l1=l[:3]
l2=l[3:]
l1,l2
# Out:
# ([1, 2, 3], [4, 5])

# %%
invoice = """
...
0.....6.................................40........52...55........
... 1909  Pimoroni PiBrella                     $17.50 3   $52.50
... 1489  6mm Tactile Switch x20                 $4.95 2    $9.90
... 1510  Panavise Jr. - PV-201                 $28.00 1   $28.00
... 1601  PiTFT Mini Kit 320x240                $34.95 1   $34.95
... """
SKU = slice(0, 6)
DESCRIPTION = slice(6, 40)
UNIT_PRICE = slice(40, 52)
QUANTITY = slice(52, 55)
ITEM_TOTAL = slice(55, None)
line_items = invoice.split('\n')[2:]
for item in line_items:
    print(item[SKU], item[ITEM_TOTAL])
# Out:
# 0..... 55........
# 1909   $52.50
# 1489    $9.90
# 1510   $28.00
# 1601   $34.95

# %%
a=list(range(10)) # Замена любого количества элементов по срезу на любое другое количество элементов
a[2:5] = [20, 30]
a
# Out:
# [0, 1, 20, 30, 5, 6, 7, 8, 9]

# %%
b=list(range(10))
b[2::5]=[100,200]
b
# Out:
# [0, 1, 100, 3, 4, 5, 6, 200, 8, 9]

# %%
board = [['_'] * 3 for i in range(9)]
board[3:6] = [['_', 'X', '_'] for _ in range(3)]
board
# Out:
# [['_', '_', '_'],
#  ['_', '_', '_'],
#  ['_', '_', '_'],
#  ['_', 'X', '_'],
#  ['_', 'X', '_'],
#  ['_', 'X', '_'],
#  ['_', '_', '_'],
#  ['_', '_', '_'],
#  ['_', '_', '_']]

# %%
l = [28, 14, '28', 5, '9', '1', 0, 6, '23', 19]
sorted(l, key=int)
# Out:
# [0, '1', 5, 6, '9', 14, 19, '23', 28, '28']

# %%
l = [28, 14, '28', 5, '9', '1', 0, 6, '23', 19]
sorted(l, key=str)
# Out:
# [0, '1', 14, 19, '23', 28, '28', 5, 6, '9']
